# %%
import os
os.chdir("/Users/678094/Desktop/Goodreads")

print(os.getcwd())
# Out:
# C:\Users\678094\Desktop\Goodreads

# %%
import requests
import bs4
import re
import numpy as np
import pandas as pd

# %%
page1 = 'https://www.goodreads.com/genres/list?page=1'
page2 = 'https://www.goodreads.com/genres/list?page=2'
page3 = 'https://www.goodreads.com/genres/list?page=3'
page4 = 'https://www.goodreads.com/genres/list?page=4'
page5 = 'https://www.goodreads.com/genres/list?page=5'

# %%
req1, req2, req3, req4, req5 = [requests.get(page)
                                for page in [page1, page2, page3, page4, page5]]

# %%
type(req5)
# Out:
# requests.models.Response

# %%
soup1, soup2, soup3, soup4, soup5 = [bs4.BeautifulSoup(page.text, "lxml")
                                    for page in [req1, req2, req3, req4, req5] ]

# %%
type(soup1)
# Out:
# bs4.BeautifulSoup

# %%
soup1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-97833c5f653f> in <cell line: 1>()
# ----> 1 soup1
#
# NameError: name 'soup1' is not defined

# %%
genreList = []
for soup in [soup1, soup2, soup3, soup4, soup5]:
    for a in soup.find_all('a', href = re.compile("/genres/")):
        if a.text:
            genreList.append(a['href'].split("/", 2)[2])

# %%
genreList[0:10]
# Out:
# ['art',
#  'biography',
#  'business',
#  'children-s',
#  'christian',
#  'classics',
#  'comics',
#  'cookbooks',
#  'ebooks',
#  'fantasy']

# %%
len(genreList)
# Out:
# 1548

# %%
genres = pd.DataFrame(genreList).drop_duplicates(0)

# %%
genres.columns = ['tag_name']

# %%
genres
# Out:
#                             tag_name
# 0                                art
# 1                          biography
# 2                           business
# 3                         children-s
# 4                          christian
# 5                           classics
# 6                             comics
# 7                          cookbooks
# 8                             ebooks
# 9                            fantasy
# 10                           fiction
# 11                    graphic-novels
# 12                historical-fiction
# 13                           history
# 14                            horror
# 15                            memoir
# 16                             music
# 17                           mystery
# 18                       non-fiction
# 19                            poetry
# 20                        psychology
# 21                           romance
# 22                           science
# 23                   science-fiction
# 24                         self-help
# 25                            sports
# 26                          thriller
# 27                            travel
# 28                       young-adult
# 58                      10th-century
# ...                              ...
# 1448        women-and-gender-studies
# 1513                          womens
# 1514                  womens-fiction
# 1515                   womens-rights
# 1516                  womens-studies
# 1517                    wonder-woman
# 1518                        woodwork
# 1519                           words
# 1520                   world-history
# 1521               world-of-darkness
# 1522               world-of-warcraft
# 1523                     world-war-i
# 1524                    world-war-ii
# 1525                         writing
# 1526            wwii-related-fiction
# 1527                           x-men
# 1528                            yaoi
# 1530        young-adult-contemporary
# 1531             young-adult-fantasy
# 1532  young-adult-historical-fiction
# 1533          young-adult-paranormal
# 1534             young-adult-romance
# 1535     young-adult-science-fiction
# 1536                   young-readers
# 1537                            yuri
# 1538                          zambia
# 1539                             zen
# 1540                        zimbabwe
# 1541                         zombies
# 1542              %E6%BC%AB%E7%94%BB
#
# [1237 rows x 1 columns]

# %%
genres.to_csv('genres.csv')
